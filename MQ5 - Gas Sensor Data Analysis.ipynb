# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
dtype={'user_id': int}

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30,30)

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (30,30)

pd.options.mode.chained_assignment = None



# read the data
df = pd.read_csv(r"C:\Users\Admin\MQ5-GasSensor_data.csv",encoding='ISO-8859–1')

# shape and data types of the data
print(df.shape)
print(df.dtypes)

# select numeric columns
df_numeric = df.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

# select non numeric columns
df_non_numeric = df.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# (299, 12)
# id            int64
# time\t      float64
# R1          float64
# R2          float64
# R3          float64
# R4          float64
# R5          float64
# R6          float64
# R7          float64
# R8          float64
# Temp        float64
# Humidity    float64
# dtype: object
# ['id' 'time\t' 'R1' 'R2' 'R3' 'R4' 'R5' 'R6' 'R7' 'R8' 'Temp' 'Humidity']
# []

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 5
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %%
# histogram of R1
df['R1'].hist(bins=100,xrot=90)

# %%
# histogram of R2
df['R2'].hist(bins=100,xrot=90)

# %%
# histogram of R3 
df['R3'].hist(bins=100,xrot=90)

# %%
# histogram of R4
df['R4'].hist(bins=100,xrot=90)

# %%
# histogram of R5
df['R5'].hist(bins=100,xrot=90)

# %%
# histogram of R6
df['R6'].hist(bins=100,xrot=90)

# %%
# histogram of R7
df['R7'].hist(bins=100,xrot=90)

# %%
# histogram of R8
df['R8'].hist(bins=100,xrot=90)

# %%
# histogram of Temp
df['Temp'].hist(bins=100,xrot=90)

# %%
# histogram of Humidity
df['Humidity'].hist(bins=100,xrot=90)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis:

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 35
plt.rcParams["figure.figsize"] = fig_size

# %%
# Let's calculate the percentage of temperature
df.Temp.value_counts(normalize=True)

#plot the bar graph of percentage temperature
df.Temp.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# ### Categorical Ordered Univariate Analysis:

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 5
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### Scatter Plot

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 30
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %%
plt.tick_params(axis='x', rotation=90)
#plot the scatter plot of Temperature and Humidity variable in data
plt.scatter(df.Temp,df.Humidity)
plt.show()

# %% [markdown]
# ### Numeric - Categorical Analysis

# %%
#groupby the temperature to find the mean of the temperatures
df.groupby('Temp').median()
# Out:
#                  id    time\t        R1         R2         R3         R4  \
# Temp
# 26.1275  184.000000 -0.910776  12.99030  10.580200  10.647000  11.913200
# 26.1277  185.000000 -0.910487  12.99080  10.580400  10.647000  11.913000
# 26.1280  186.000000 -0.910209  12.99200  10.580600  10.647100  11.913100
# 26.1282  187.000000 -0.909931  12.99210  10.580800  10.647300  11.913500
# 26.1283  185.500000 -0.910354  12.99110  10.580450  10.647200  11.913350
# ...             ...       ...       ...        ...        ...        ...
# 26.2705   20.333333 -0.994336  12.85430  10.370000  10.436033  11.670367
# 26.2706   20.500000 -0.994286  12.85445  10.370400  10.436250  11.670600
# 26.2707   20.333333 -0.994340  12.85470  10.369933  10.436400  11.670567
# 26.2708   17.000000 -0.995270  12.85490  10.369400  10.436600  11.670500
# 26.2709   25.000000 -0.993024  12.85450  10.370100  10.435300  11.670700
#
#                 R5         R6        R7        R8  Humidity
# Temp
# ...

# %%
#groupby the Humidity to find the mean 
df.groupby('Humidity').median()
# Out:
#              id    time\t       R1       R2       R3       R4       R5  \
# Humidity
# 58.7759   299.0 -0.878550  13.0171  10.6033  10.6619  11.9294  13.8237
# 58.7785   298.0 -0.878828  13.0168  10.6028  10.6620  11.9296  13.8237
# 58.7814   297.0 -0.879106  13.0165  10.6025  10.6622  11.9297  13.8234
# 58.7846   296.0 -0.879384  13.0161  10.6017  10.6621  11.9295  13.8229
# 58.7882   295.0 -0.879662  13.0157  10.6013  10.6619  11.9292  13.8225
# ...         ...       ...      ...      ...      ...      ...      ...
# 58.9804    63.0 -0.944670  12.9781  10.5534  10.6297  11.8836  13.7701
# 58.9905     4.0 -0.998916  12.8602  10.3686  10.4370  11.6697  13.4921
# 59.0093     3.0 -0.999194  12.8607  10.3686  10.4370  11.6696  13.4924
# 59.0299     2.0 -0.999472  12.8617  10.3682  10.4375  11.6697  13.4927
# 59.0528     1.0 -0.999750  12.8621  10.3683  10.4383  11.6699  13.4931
#
#                R6       R7       R8     Temp
# Humidity
# 58.7759   13.5444  8.07053  8.79299  26.1745
# ...

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 7
plt.rcParams["figure.figsize"] = fig_size

# %%
#plot the box plot of temp and humidity
sns.boxplot(df.Temp, df.Humidity)
plt.xticks(rotation=45,ha='right')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
#adjusting graph size for better visualization
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 5
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# ### Heatmap

# %%
result = pd.pivot_table(data=df, index='Temp', columns='Humidity',values='R8')
print(result)

#create heat map of temp vs humidity
sns.heatmap(result, annot=True, cmap = 'coolwarm', center=0.117)
plt.show()
# Out:
# Humidity  58.7759  58.7785  58.7814  58.7846  58.7882  58.7921  58.7964  \
# Temp
# 26.1275       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.1277       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.1280       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.1282       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.1283       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...           ...      ...      ...      ...      ...      ...      ...
# 26.2705       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.2706       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.2707       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.2708       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 26.2709       NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# Humidity  58.8012  58.8033  58.8055  ...  58.9764  58.9765  58.9774  58.9785  \
# ...
